# %% [markdown]
# # Sentinel 3 乐趣

# %% [markdown]
# ## 练习 10.1：读取 OLCI 数据从本页的 satpy 读取器表中确定使用哪个读取器：https://satpy.readthedocs.io/en/latest/index.html
# - 然后从它生成一个真彩色合成图像。

# %% [markdown]
# ## 练习 10.2：读取 SLSTR 数据请参考本页的 satpy 读取器表格以确定要使用的读取器：https://satpy.readthedocs.io/en/latest/index.html
# 然后从它创建一个概览Sun综合体。

# %% [markdown]
# ## 练习 10.3：着色选择一个合适的颜色映射表，并对SLSTR热通道在~11微米处的数据进行颜色渲染

# %% [markdown]
# ## 练习 10.4将练习1和练习3的结果结合起来，创建一个夹层复合材料
