# %% [markdown]
# # 预测极轨卫星过境
# 在本教程中，我们将学习如何使用 pyorbital 预测极地卫星的过境。

# %% [markdown]
# ## 练习 3.1查阅pyorbital文档，计算NOAA-20当前的位置，并预测接下来24小时内NOAA-20在EUMETSAT总部上空的过顶时间。https://pyorbital.readthedocs.io/en/latest/

# %% [markdown]
# ## 练习 3.2（高级）在地图上绘制第一个计算出的过境。这可以通过使用 pytroll-schedule 包来实现，你需要用 pip 安装它。你还需要安装 Basemap 库。使用 `trollsched.satpass.Pass` 类。这方面的文档较为稀缺，因此请查看源代码以了解其工作原理。
# 如果你觉得自己已经非常熟练，请将此绘图功能转换为cartopy（因为basemap已弃用）。

# %% [markdown]
# ## 练习 3.3在之前计算的子卫星坐标处计算太阳天顶角。
